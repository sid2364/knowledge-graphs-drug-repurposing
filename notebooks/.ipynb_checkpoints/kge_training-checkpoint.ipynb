# %% [markdown]
# Training KGEs(
#
# Refs:-
# https://mlflow.org/docs/latest/ml/tracking/quickstart/
# https://pykeen.readthedocs.io/en/stable/tutorial/models.html

# %%
import os
from pathlib import Path
from datetime import datetime
import torch
import pandas as pd
from tqdm import tqdm

import mlflow
from mlflow.models import infer_signature

# %%
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline
from pykeen.trackers import MLFlowResultTracker
from pykeen.pipeline import pipeline
from pykeen.trackers import MLFlowResultTracker

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
SEED = 23
# Out:
# Device: cpu

# %%
MLFLOW_TRACKING_URI="file:./mlruns"
MLFLOW_EXPERIMENT="KGE Training (TransE, DistMult and ComplEx) with PharMeBINet"

# mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(MLFLOW_EXPERIMENT)
# Out:
# <Experiment: artifact_location='file:///home/sid/Study/knowledge-graphs-drug-repurposing/notebooks/mlruns/981545609083190387', creation_time=1758889240882, experiment_id='981545609083190387', last_update_time=1758889240882, lifecycle_stage='active', name='KGE Training (TransE, DistMult and ComplEx) with PharMeBINet', tags={}>

# %%
ROOT = Path().resolve()/".." # FIXME hacky way to go back, find a way to reference actual project root
DATA_DIR = ROOT/"data"/"processed"/"pharmebinet"
RUNS_DIR = ROOT/"runs"/"pykeen_kge_pharmebinet"
RUNS_DIR.mkdir(parents=True, exist_ok=True)

TRIPLES = DATA_DIR/"triples.tsv"
E2ID = DATA_DIR/"entity2id.csv"
R2ID = DATA_DIR/"relation2id.csv"
ETYPE = DATA_DIR/"entity_types.csv"

# double check if it's all there
for p in [TRIPLES, E2ID, R2ID, ETYPE]:
    assert p.exists(), f"Missing file: {p}"

# print("entity types")
# display(pd.read_csv(ETYPE, nrows=5))
print("triples:")
display(pd.read_csv(TRIPLES, nrows=5))
print("relation to ID")
display(pd.read_csv(R2ID, nrows=30))
# Out:
# triples:
#                 relation\thead\ttail
# 0  INVOLVED_IN_PiiBP\t192000\t304346
# 1  INVOLVED_IN_PiiBP\t192000\t297825
# 2  INVOLVED_IN_PiiBP\t192000\t297959
# 3  INVOLVED_IN_PiiBP\t192000\t317503
# 4  INVOLVED_IN_PiiBP\t192000\t295456
# relation to ID
#                                              relation  idx
# 0                             ACTS_UPSTREAM_OF_GauoBP    0
# 1           ACTS_UPSTREAM_OF_NEGATIVE_EFFECT_GauoneBP    1
# 2           ACTS_UPSTREAM_OF_NEGATIVE_EFFECT_PauoneBP    2
# 3                 ACTS_UPSTREAM_OF_OR_WITHIN_GauoowBP    3
# 4   ACTS_UPSTREAM_OF_OR_WITHIN_NEGATIVE_EFFECT_Gau...    4
# 5   ACTS_UPSTREAM_OF_OR_WITHIN_NEGATIVE_EFFECT_Pau...    5
# 6   ACTS_UPSTREAM_OF_OR_WITHIN_POSITIVE_EFFECT_Gau...    6
# 7   ACTS_UPSTREAM_OF_OR_WITHIN_POSITIVE_EFFECT_Pau...    7
# 8                 ACTS_UPSTREAM_OF_OR_WITHIN_PauoowBP    8
# 9           ACTS_UPSTREAM_OF_POSITIVE_EFFECT_GauopeBP    9
# 10          ACTS_UPSTREAM_OF_POSITIVE_EFFECT_PauopeBP   10
# 11                            ACTS_UPSTREAM_OF_PauoBP   11
# 12                         AFFECTS_DEGENERATION_CHadP   12
# 13                         AFFECTS_DEGENERATION_GadCH   13
# 14                         AFFECTS_DEGENERATION_PadCH   14
# 15                                   ASSOCIATES_CAaCH   15
# 16                                    ASSOCIATES_CAaG   16
# 17                                   ASSOCIATES_CAaPC   17
# 18                                   ASSOCIATES_CAaPT   18
# 19                                    ASSOCIATES_CAaV   19
# 20                                   ASSOCIATES_CHaBP   20
# 21                                   ASSOCIATES_CHaCC   21
# 22                                   ASSOCIATES_CHaCH   22
# 23                                    ASSOCIATES_CHaG   23
# 24                                   ASSOCIATES_CHaMF   24
# 25                                    ASSOCIATES_CHaP   25
# 26                                    ASSOCIATES_CaPW   26
# 27                                     ASSOCIATES_DaG   27
# 28                                    ASSOCIATES_GaCH   28
# 29                                    ASSOCIATES_PTaG   29

# %%
# load mappings
e2 = pd.read_csv(E2ID, dtype={"entity_id": str, "idx": int})
r2 = pd.read_csv(R2ID, dtype={"relation": str, "idx": int})

entity_to_id = dict(zip(e2["entity_id"], e2["idx"]))
relation_to_id = dict(zip(r2["relation"],  r2["idx"]))

# and triples (header: head, relation, tail) -------------------
triples_df = pd.read_csv(TRIPLES, sep="\t", dtype=str, usecols=["head", "relation", "tail"]) # pls don't crash
labeled_triples = triples_df[["head", "relation", "tail"]].values

tf_all = TriplesFactory.from_labeled_triples(
    triples=labeled_triples,
    entity_to_id=entity_to_id,
    relation_to_id=relation_to_id,
    create_inverse_triples=False, # TODO what does this really do?
)

tf_train, tf_valid, tf_test = tf_all.split([0.6, 0.2, 0.2], random_state=SEED)
# FIXME try different splits!!! 80/10/10

print(f"entities={tf_all.num_entities:,} relations={tf_all.num_relations:,}")
print(f"triples ---> train={tf_train.num_triples:,} valid={tf_valid.num_triples:,} test={tf_test.num_triples:,}")
# Out:
# entities=2,653,751 relations=208
# triples ---> train=9,526,657 valid=3,175,553 test=3,175,553

# %% [markdown]
# Reference: https://pykeen.readthedocs.io/en/stable/api/pykeen.pipeline.pipeline.html

# %%
def train_model(name: str, model_kwargs: dict, use_inverses: bool, out_dir: Path):
    out_dir.mkdir(parents=True, exist_ok=True)

    tr = tf_train if not use_inverses else tf_train.create_inverse_triples()
    va = tf_valid if not use_inverses else tf_valid.create_inverse_triples()
    te = tf_test if not use_inverses else tf_test.create_inverse_triples()

    # PyKEEN MLflow tracker (it starts/uses a run under the experiment)
    run_name = f"{name}-{datetime.now().strftime('%Y%m%d-%H%M%S')}"
    tracker = MLFlowResultTracker(
        tracking_uri=MLFLOW_TRACKING_URI,
        # experiment_id=MLFLOW_EXPERIMENT,
        experiment_name=MLFLOW_EXPERIMENT,
        tags={"dataset": "PharMeBINet", "embedding_name": name},
    )

    result = pipeline(
        training=tr,
        validation=va,
        testing=te,
        model=name,
        model_kwargs=model_kwargs,
        optimizer="Adam",
        optimizer_kwargs={"lr": 1e-3},
        negative_sampler="basic",
        negative_sampler_kwargs={"num_negs_per_pos": 1},
        training_kwargs={"num_epochs": 5, "batch_size": 1024, "automatic_memory_optimization": True},
        evaluator_kwargs={"filtered": True},
        device=DEVICE,
        random_seed=SEED,
        result_tracker=tracker,
    )

    # save artifacts locally 
    result.save_to_directory(out_dir)

    # also log params/metrics/artifacts to the SAME MLflow run
    # (PyKEEN should already logged losses/metrics over time but 
    # add hyperparams + artifacts + others?)
    run_id = tracker.run.info.run_id
    with mlflow.start_run(run_id=run_id):# attach to the active run
        # Hyperparameters / switches
        mlflow.log_params({
            "model": name,
            "embedding_dim": model_kwargs.get("embedding_dim"),
            "scoring_fct_norm": model_kwargs.get("scoring_fct_norm"),
            "create_inverse_triples": use_inverses,
            "lr": 1e-3,
            "epochs": 5,
            "batch_size": 1024,
            "negatives_per_pos": 1,
            "seed": SEED,
            "device": DEVICE,
        })

        # final (filtered) metrics snapshot since pykeen already gives us this
        m = result.metric_results.to_dict()
        mlflow.log_metrics({
            "filtered_mrr": m.get("mrr", float("nan")),
            "filtered_hits@1": m.get("hits_at_1", float("nan")),
            "filtered_hits@3": m.get("hits_at_3", float("nan")),
            "filtered_hits@10": m.get("hits_at_10", float("nan")),
        })

        # artifacts
        mlflow.log_artifacts(str(out_dir)) # the whole run folder (model, metadata, etc.)
        mlflow.log_artifact(str(TRIPLES))
        mlflow.log_artifact(str(E2ID))
        mlflow.log_artifact(str(R2ID))

    print(f"[{name}] run_id={run_id}")
    metrics = result.metric_results.to_dict()
    print(f"[{name}] filtered: MRR={metrics.get('mrr'):.4f}"
          f"H@1={metrics.get('hits_at_1'):.4f}  H@10={metrics.get('hits_at_10'):.4f}")
    return result, run_id

# %%
experiments = [
    ("TransE",   {"embedding_dim": 128, "scoring_fct_norm": 1}, False), # TODO check 512 dim
    #("DistMult", {"embedding_dim": 256}, True), # TODO why inverse = True?
    #("ComplEx",  {"embedding_dim": 256}, True), # TODO why inverse = True?
]

runs = {}
for name, mkw, inv in experiments:
    print(f"====Training {name}")
    out = RUNS_DIR/name.lower()
    res, run_id = train_model(name, mkw, inv, out)
    runs[name] = run_id

pd.DataFrame({k: v.metric_results.to_dict() for k, v in results.items()}).T
# Out:
# ====Training TransE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9     print(f"====Training {name}")
#      10     out = RUNS_DIR/name.lower()
# ---> 11     res, run_id = train_model(name, mkw, inv, out)
#      12     runs[name] = run_id
#      14 pd.DataFrame({k: v.metric_results.to_dict() for k, v in results.items()}).T
#
# Cell In[7], line 17, in train_model(name, model_kwargs, use_inverses, out_dir)
#       9 run_name = f"{name}-{datetime.now().strftime('%Y%m%d-%H%M%S')}"
#      10 tracker = MLFlowResultTracker(
#      11     tracking_uri=MLFLOW_TRACKING_URI,
#      12     # experiment_id=MLFLOW_EXPERIMENT,
#      13     experiment_name=MLFLOW_EXPERIMENT,
#      14     tags={"dataset": "PharMeBINet", "embedding_name": name},
#      15 )
# ---> 17 result = pipeline(
#      18     training=tr,
#      19     validation=va,
#      20     testing=te,
#      21     model=name,
#      22     model_kwargs=model_kwargs,
#      23     optimizer="Adam",
#      24     optimizer_kwargs={"lr": 1e-3},
#      25     negative_sampler="basic",
#      26     negative_sampler_kwargs={"num_negs_per_pos": 1},
#      27     training_kwargs={"num_epochs": 5, "batch_size": 1024},
#      28     evaluator_kwargs={"filtered": True},
#      29     device=DEVICE,
#      30     random_seed=SEED,
#      31     result_tracker=tracker,
#      32 )
#      34 # save artifacts locally
#      35 result.save_to_directory(out_dir)
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/pykeen/pipeline/api.py:1503, in pipeline(dataset, dataset_kwargs, training, testing, validation, evaluation_entity_whitelist, evaluation_relation_whitelist, model, model_kwargs, interaction, interaction_kwargs, dimensions, loss, loss_kwargs, regularizer, regularizer_kwargs, optimizer, optimizer_kwargs, clear_optimizer, lr_scheduler, lr_scheduler_kwargs, training_loop, training_loop_kwargs, negative_sampler, negative_sampler_kwargs, epochs, training_kwargs, stopper, stopper_kwargs, evaluator, evaluator_kwargs, evaluation_kwargs, result_tracker, result_tracker_kwargs, metadata, device, random_seed, use_testing_data, evaluation_fallback, filter_validation_when_testing, use_tqdm)
#    1490 _result_tracker.start_run(run_name=title)
#    1492 training, testing, validation = _handle_dataset(
#    1493     _result_tracker=_result_tracker,
#    1494     dataset=dataset,
#    (...)   1500     evaluation_relation_whitelist=evaluation_relation_whitelist,
#    1501 )
# -> 1503 model_instance = _handle_model(
#    1504     device=device,
#    1505     _result_tracker=_result_tracker,
#    1506     _random_seed=_random_seed,
#    1507     training=training,
#    1508     model=model,
#    1509     model_kwargs=model_kwargs,
#    1510     interaction=interaction,
#    1511     interaction_kwargs=interaction_kwargs,
#    1512     dimensions=dimensions,
#    1513     loss=loss,
#    1514     loss_kwargs=loss_kwargs,
#    1515     regularizer=regularizer,
#    1516     regularizer_kwargs=regularizer_kwargs,
#    1517 )
#    1519 training_loop_instance = _handle_training_loop(
#    1520     _result_tracker=_result_tracker,
#    1521     model_instance=model_instance,
#    (...)   1530     negative_sampler_kwargs=negative_sampler_kwargs,
#    1531 )
#    1533 evaluator_instance, evaluation_kwargs = _handle_evaluator(
#    1534     _result_tracker=_result_tracker,
#    1535     evaluator=evaluator,
#    1536     evaluator_kwargs=evaluator_kwargs,
#    1537     evaluation_kwargs=evaluation_kwargs,
#    1538 )
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/pykeen/pipeline/api.py:970, in _handle_model(device, _result_tracker, _random_seed, training, model, model_kwargs, interaction, interaction_kwargs, dimensions, loss, loss_kwargs, regularizer, regularizer_kwargs)
#     966     model_instance = cast(Model, model)
#     967     # TODO should training be reset?
#     968     # TODO should kwargs for loss and regularizer be checked and raised for?
#     969 else:
# --> 970     model_instance, model_kwargs = _build_model_helper(
#     971         model=model,
#     972         model_kwargs=model_kwargs,
#     973         loss=loss,
#     974         loss_kwargs=loss_kwargs,
#     975         regularizer=regularizer,
#     976         regularizer_kwargs=regularizer_kwargs,
#     977         _device=_device,
#     978         _random_seed=_random_seed,
#     979         training_triples_factory=training,
#     980     )
#     982 model_instance = model_instance.to(_device)
#     984 # Log model parameters
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/pykeen/pipeline/api.py:837, in _build_model_helper(model, model_kwargs, loss, loss_kwargs, _device, _random_seed, regularizer, regularizer_kwargs, training_triples_factory)
#     833     for param_name, param_default in _get_model_defaults(model).items():
#     834         model_kwargs.setdefault(param_name, param_default)
#     836 return (
# --> 837     model_resolver.make(
#     838         model,
#     839         triples_factory=training_triples_factory,
#     840         **model_kwargs,
#     841     ),
#     842     model_kwargs,
#     843 )
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/class_resolver/api.py:243, in ClassResolver.make(self, query, pos_kwargs, **kwargs)
#     241         if any(text in e.args[0] for text in MISSING_ARGS):
#     242             raise UnexpectedKeywordError(cls) from None
# --> 243         raise e
#     245 # An instance was passed, and it will go through without modification.
#     246 return query
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/class_resolver/api.py:237, in ClassResolver.make(self, query, pos_kwargs, **kwargs)
#     235 cls: type[X] = self.lookup(query)
#     236 try:
# --> 237     return cls(**(pos_kwargs or {}), **kwargs)
#     238 except TypeError as e:
#     239     if "required keyword-only argument" in e.args[0]:
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/pykeen/models/unimodal/trans_e.py:87, in TransE.__init__(self, embedding_dim, scoring_fct_norm, power_norm, entity_initializer, entity_constrainer, relation_initializer, relation_constrainer, regularizer, regularizer_kwargs, **kwargs)
#      41 def __init__(
#      42     self,
#      43     *,
#    (...)     53     **kwargs,
#      54 ) -> None:
#      55     r"""Initialize TransE.
#      56
#      57     :param embedding_dim: The entity embedding dimension $d$. Is usually $d \in [50, 300]$.
#    (...)     85             ``scoring_fct_norm`` and ``power_norm``.
#      86     """
# ---> 87     super().__init__(
#      88         interaction=TransEInteraction,
#      89         interaction_kwargs=dict(p=scoring_fct_norm, power_norm=power_norm),
#      90         entity_representations_kwargs=dict(
#      91             shape=embedding_dim,
#      92             initializer=entity_initializer,
#      93             constrainer=entity_constrainer,
#      94             regularizer=regularizer,
#      95             regularizer_kwargs=regularizer_kwargs,
#      96         ),
#      97         relation_representations_kwargs=dict(
#      98             shape=embedding_dim,
#      99             initializer=relation_initializer,
#     100             constrainer=relation_constrainer,
#     101             regularizer=regularizer,
#     102             regularizer_kwargs=regularizer_kwargs,
#     103         ),
#     104         **kwargs,
#     105     )
#
# File ~/Study/knowledge-graphs-drug-repurposing/kgdr_env/lib/python3.12/site-packages/pykeen/models/nbase.py:348, in ERModel.__init__(self, triples_factory, interaction, interaction_kwargs, entity_representations, entity_representations_kwargs, relation_representations, relation_representations_kwargs, skip_checks, **kwargs)
#     325 """Initialize the module.
#     326
#     327 :param triples_factory:
#    (...)    342     Keyword arguments to pass to the base model
#     343 """
#     344 # TODO: support "broadcasting" representation regularizers?
#     345 # e.g. re-use the same regularizer for everything; or
#     346 # pass a dictionary with keys "entity"/"relation";
#     347 # values are either a regularizer hint (=the same regularizer for all repr); or a sequence of appropriate length
# --> 348 super().__init__(triples_factory=triples_factory, **kwargs)
#     349 self.interaction = interaction_resolver.make(interaction, pos_kwargs=interaction_kwargs)
#     350 self.entity_representations = self._build_representations(
#     351     triples_factory=triples_factory,
#     352     representations=entity_representations,
#    (...)    355     skip_checks=skip_checks,
#     356 )
#
# TypeError: Model.__init__() got an unexpected keyword argument 'automatic_memory_optimization'
